# %%
using Pkg; Pkg.activate("../")
# Out:
#   Activating project at `~/.nextcloud/src/UnitaryTransformations.jl`

# %%
using UnitaryTransformations, Symbolics, 
import QuantumAlgebra: sumindex
# Out:
# [ Info: Precompiling UnitaryTransformations [2aaaa306-0b60-42d5-89de-b99f2615351e] (cache misses: include_dependency fsize change (4), mismatched flags (14))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Info: Skipping precompilation due to precompilable error. Importing UnitaryTransformations [2aaaa306-0b60-42d5-89de-b99f2615351e].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling QuantumAlgebra [1b9008d5-2a9d-4901-8cfb-44bb87795b64] (cache misses: include_dependency fsize change (2), wrong source (4), mismatched flags (12))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# [ Info: Precompiling QuantumAlgebraSymbolicsExt [3b6ee111-5a47-5db4-b143-f3c523ba0196] (cache misses: wrong dep version loaded (6), mismatched flags (14))
#
# ...
